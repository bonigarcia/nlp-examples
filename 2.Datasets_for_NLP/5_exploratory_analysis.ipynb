# %% [markdown]
# **Vocabulary size**

# %%
import nltk
from nltk.corpus import gutenberg
nltk.download("gutenberg")

all_words = gutenberg.words("melville-moby_dick.txt")
print("Total words", len(all_words))

vocabulary = sorted(set(all_words))
print("Vocabulary size", len(vocabulary))
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Total words 260819
# Vocabulary size 19317

# %% [markdown]
# **Lexical diversity**

# %%
def lexical_diversity(all_words, vocabulary):
  return len(vocabulary) / len(all_words)

ld = lexical_diversity(all_words, vocabulary)
print("Lexical diversity of Moby Dick", ld)
# Out:
# Lexical diversity of Moby Dick 0.07406285585022564

# %% [markdown]
# **Frequency distribution**

# %%
from nltk import FreqDist

frequency_dist_all_words = FreqDist(all_words)
frequency_dist_all_words.plot(30)

# %% [markdown]
# **Word cloud**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wcloud = WordCloud().generate_from_frequencies(frequency_dist_all_words)
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
